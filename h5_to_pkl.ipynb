# %%
import h5py
import pickle
import numpy as np
import os
from datetime import datetime

# %%
def get_img_order(entity2id_file, imageindex_file, img_order_file):
    img_order = []
    
    with open(entity2id_file, 'r', encoding='utf-8') as f:
        for line in f:
            entity_id = line.strip().split()[0]
            
            with open(imageindex_file, 'r', encoding='utf-8') as img_file:
                found = False
                for img_line in img_file:
                    img_id, img_url = img_line.strip().split('\t')
                    if entity_id == img_id:
                        img_order.append(img_url)
                        found = True
                        break
                
                if not found:
                    img_order.append('ERROR: ' + entity_id + ' not found in ' + imageindex_file)
    
    with open(img_order_file, 'w', encoding='utf-8') as f:
        for img_url in img_order:
            f.write(img_url + '\n')
        print('图像顺序已保存到' + img_order_file)

# %%
get_img_order('../IMF-Pytorch/datasets/DB15K/entity2id.txt', '../mmkb-0.2/DB15K/DB15K_ImageIndex.txt', 'DB15K/img_order.txt')

# %%
def list_h5_datasets(h5_file):
    with h5py.File(h5_file, 'r') as file:
        datasets = list(file.keys())
    return datasets


h5_file = '../mmkb-0.2/DB15K_ImageData.h5'
datasets = list_h5_datasets(h5_file)
print(datasets)
# Out:
# ['DBIMG00001', 'DBIMG00002', 'DBIMG00003', 'DBIMG00004', 'DBIMG00005', 'DBIMG00006', 'DBIMG00007', 'DBIMG00008', 'DBIMG00009', 'DBIMG00010', 'DBIMG00011', 'DBIMG00012', 'DBIMG00013', 'DBIMG00014', 'DBIMG00015', 'DBIMG00016', 'DBIMG00017', 'DBIMG00018', 'DBIMG00019', 'DBIMG00020', 'DBIMG00021', 'DBIMG00022', 'DBIMG00023', 'DBIMG00024', 'DBIMG00025', 'DBIMG00026', 'DBIMG00027', 'DBIMG00028', 'DBIMG00029', 'DBIMG00030', 'DBIMG00031', 'DBIMG00032', 'DBIMG00033', 'DBIMG00034', 'DBIMG00035', 'DBIMG00036', 'DBIMG00037', 'DBIMG00038', 'DBIMG00039', 'DBIMG00040', 'DBIMG00041', 'DBIMG00042', 'DBIMG00043', 'DBIMG00044', 'DBIMG00045', 'DBIMG00046', 'DBIMG00047', 'DBIMG00048', 'DBIMG00049', 'DBIMG00050', 'DBIMG00051', 'DBIMG00052', 'DBIMG00053', 'DBIMG00054', 'DBIMG00055', 'DBIMG00056', 'DBIMG00057', 'DBIMG00058', 'DBIMG00059', 'DBIMG00060', 'DBIMG00061', 'DBIMG00062', 'DBIMG00063', 'DBIMG00064', 'DBIMG00065', 'DBIMG00066', 'DBIMG00067', 'DBIMG00068', 'DBIMG00069', 'DBIMG00070', 'DBIMG00071', 'DBIMG00072', 'DBIMG00073', 'DBIMG00074', 'DBIMG00075', 'DBIMG00076', 'DBIMG00077', 'DBIMG00078', 'DBIMG00079', 'DBIMG00080', 'DBIMG00081', 'DBIMG00082', 'DBIMG00083', 'DBIMG00084', 'DBIMG00085', 'DBIMG00086', 'DBIMG00087', 'DBIMG00088', 'DBIMG00089', 'DBIMG00090', 'DBIMG00091', 'DBIMG00092', 'DBIMG00093', 'DBIMG00094', 'DBIMG00095', 'DBIMG00096', 'DBIMG00097', 'DBIMG00098', 'DBIMG00099', 'DBIMG00100', 'DBIMG00101', 'DBIMG00102', 'DBIMG00103', 'DBIMG00104', 'DBIMG00105', 'DBIMG00106', 'DBIMG00107', 'DBIMG00108', 'DBIMG00109', 'DBIMG00110', 'DBIMG00111', 'DBIMG00112', 'DBIMG00113', 'DBIMG00114', 'DBIMG00115', 'DBIMG00116', 'DBIMG00117', 'DBIMG00118', 'DBIMG00119', 'DBIMG00120', 'DBIMG00121', 'DBIMG00122', 'DBIMG00123', 'DBIMG00124', 'DBIMG00125', 'DBIMG00126', 'DBIMG00127', 'DBIMG00128', 'DBIMG00129', 'DBIMG00130', 'DBIMG00131', 'DBIMG00132', 'DBIMG00133', 'DBIMG00134', 'DBIMG00135', 'DBIMG00136', 'DBIMG00137', 'DBIMG00138', 'DBIMG00139', 'DBIMG00140', 'DBIMG00141', 'DBIMG00142', 'DBIMG00143', 'DBIMG00144', 'DBIMG00145', 'DBIMG00146', 'DBIMG00147', 'DBIMG00148', 'DBIMG00149', 'DBIMG00150', 'DBIMG00151', 'DBIMG00152', 'DBIMG00153', 'DBIMG00154', 'DBIMG00155', 'DBIMG00156', 'DBIMG00157', 'DBIMG00158', 'DBIMG00159', 'DBIMG00160', 'DBIMG00161', 'DBIMG00162', 'DBIMG00163', 'DBIMG00164', 'DBIMG00165', 'DBIMG00166', 'DBIMG00167', 'DBIMG00168', 'DBIMG00169', 'DBIMG00170', 'DBIMG00171', 'DBIMG00172', 'DBIMG00173', 'DBIMG00174', 'DBIMG00175', 'DBIMG00176', 'DBIMG00177', 'DBIMG00178', 'DBIMG00179', 'DBIMG00180', 'DBIMG00181', 'DBIMG00182', 'DBIMG00183', 'DBIMG00184', 'DBIMG00185', 'DBIMG00186', 'DBIMG00187', 'DBIMG00188', 'DBIMG00189', 'DBIMG00190', 'DBIMG00191', 'DBIMG00192', 'DBIMG00193', 'DBIMG00194', 'DBIMG00195', 'DBIMG00196', 'DBIMG00197', 'DBIMG00198', 'DBIMG00199', 'DBIMG00200', 'DBIMG00201', 'DBIMG00202', 'DBIMG00203', 'DBIMG00204', 'DBIMG00205', 'DBIMG00206', 'DBIMG00207', 'DBIMG00208', 'DBIMG00209', 'DBIMG00210', 'DBIMG00211', 'DBIMG00212', 'DBIMG00213', 'DBIMG00214', 'DBIMG00215', 'DBIMG00216', 'DBIMG00217', 'DBIMG00218', 'DBIMG00219', 'DBIMG00220', 'DBIMG00221', 'DBIMG00222', 'DBIMG00223', 'DBIMG00224', 'DBIMG00225', 'DBIMG00226', 'DBIMG00227', 'DBIMG00228', 'DBIMG00229', 'DBIMG00230', 'DBIMG00231', 'DBIMG00232', 'DBIMG00233', 'DBIMG00234', 'DBIMG00235', 'DBIMG00236', 'DBIMG00237', 'DBIMG00238', 'DBIMG00239', 'DBIMG00240', 'DBIMG00241', 'DBIMG00242', 'DBIMG00243', 'DBIMG00244', 'DBIMG00245', 'DBIMG00246', 'DBIMG00247', 'DBIMG00248', 'DBIMG00249', 'DBIMG00250', 'DBIMG00251', 'DBIMG00252', 'DBIMG00253', 'DBIMG00254', 'DBIMG00255', 'DBIMG00256', 'DBIMG00257', 'DBIMG00258', 'DBIMG00259', 'DBIMG00260', 'DBIMG00261', 'DBIMG00262', 'DBIMG00263', 'DBIMG00264', 'DBIMG00265', 'DBIMG00266', 'DBIMG00267', 'DBIMG00268', 'DBIMG00269', 'DBIMG00270', 'DBIMG00271', 'DBIMG00272', 'DBIMG00273', 'DBIMG00274', 'DBIMG00275', 'DBIMG00276', 'DBIMG00277', 'DBIMG00278', 'DBIMG00279', 'DBIMG00280', 'DBIMG00281', 'DBIMG00282', 'DBIMG00283', 'DBIMG00284', 'DBIMG00285', 'DBIMG002 ...

# %%
def convert_h5_to_pkl(h5_file, pkl_file):
    with h5py.File(h5_file, 'r') as file:
        data = file['FBIMG00001'][:]
    with open(pkl_file, 'wb') as file:
        pickle.dump(data, file)

# %%
def merge_h5_to_pkl(h5_file, pkl_file, img_order_file):
    with open(img_order_file, 'r', encoding='utf-8') as f:
        img_order = [line.strip() for line in f]
    
    with h5py.File(h5_file, 'r') as file:
        datasets = list(file.keys())
        data = []
        total_datasets = len(img_order)
        
        for i, dataset in enumerate(img_order):
            if dataset.startswith('ERROR:') or dataset not in datasets:
                data.append(np.zeros(4096).tolist())
                continue
            
            data.append(np.squeeze(file[dataset][:]).tolist())
            
            if (i + 1) % 100 == 0:
                timestamp = datetime.now().strftime("[%H:%M:%S]")
                print(f"{timestamp} 已转换{i + 1}/{total_datasets}个数据集，当前数据集：{dataset}")
    
    with open(pkl_file, 'wb') as file:
        timestamp = datetime.now().strftime("[%H:%M:%S]")
        pickle.dump(data, file)
        print(f"{timestamp} {pkl_file} 保存成功")

# %%
dataset_name = 'YAGO15K'
h5_file = f'../mmkb-0.2/{dataset_name}_ImageData.h5'
pkl_file = f'{dataset_name}/img_features.pkl'
entity2id_file = f'../IMF-Pytorch/datasets/{dataset_name}/entity2id.txt'
imageindex_file = f'../mmkb-0.2/{dataset_name}/{dataset_name}_ImageIndex.txt'
img_order_file = f'{dataset_name}/img_order.txt'

if not os.path.exists(img_order_file):
    get_img_order(entity2id_file, imageindex_file, img_order_file)

merge_h5_to_pkl(h5_file, pkl_file, img_order_file)
# Out:
# 图像顺序已保存到YAGO15K/img_order.txt
# [21:37:19] 已转换100/15404个数据集，当前数据集：YAGOIMG04277
# [21:37:19] 已转换200/15404个数据集，当前数据集：YAGOIMG01075
# [21:37:19] 已转换300/15404个数据集，当前数据集：YAGOIMG08930
# [21:37:19] 已转换500/15404个数据集，当前数据集：YAGOIMG02337
# [21:37:19] 已转换700/15404个数据集，当前数据集：YAGOIMG06384
# [21:37:19] 已转换900/15404个数据集，当前数据集：YAGOIMG09342
# [21:37:20] 已转换1000/15404个数据集，当前数据集：YAGOIMG04101
# [21:37:20] 已转换1300/15404个数据集，当前数据集：YAGOIMG01475
# [21:37:20] 已转换1400/15404个数据集，当前数据集：YAGOIMG01894
# [21:37:20] 已转换1500/15404个数据集，当前数据集：YAGOIMG09169
# [21:37:20] 已转换1600/15404个数据集，当前数据集：YAGOIMG05597
# [21:37:20] 已转换1700/15404个数据集，当前数据集：YAGOIMG00825
# [21:37:20] 已转换1800/15404个数据集，当前数据集：YAGOIMG10351
# [21:37:20] 已转换1900/15404个数据集，当前数据集：YAGOIMG07595
# [21:37:20] 已转换2000/15404个数据集，当前数据集：YAGOIMG06802
# [21:37:20] 已转换2100/15404个数据集，当前数据集：YAGOIMG03271
# [21:37:21] 已转换2300/15404个数据集，当前数据集：YAGOIMG02460
# [21:37:21] 已转换2400/15404个数据集，当前数据集：YAGOIMG05440
# [21:37:21] 已转换2500/15404个数据集，当前数据集：YAGOIMG03983
# [21:37:21] 已转换2600/15404个数据集，当前数据集：YAGOIMG10757
# [21:37:21] 已转换2700/15404个数据集，当前数据集：YAGOIMG07884
# [21:37:21] 已转换2800/15404个数据集，当前数据集：YAGOIMG04085
# [21:37:21] 已转换2900/15404个数据集，当前数据集：YAGOIMG04550
# [21:37:21] 已转换3200/15404个数据集，当前数据集：YAGOIMG07018
# [21:37:21] 已转换3300/15404个数据集，当前数据集：YAGOIMG08779
# [21:37:21] 已转换3400/15404个数据集，当前数据集：YAGOIMG06951
# [21:37:21] 已转换3500/15404个数据集，当前数据集：YAGOIMG08304
# [21:37:21] 已转换3600/15404个数据集，当前数据集：YAGOIMG06670
# [21:37:22] 已转换3700/15404个数据集，当前数据集：YAGOIMG09711
# [21:37:22] 已转换3900/15404个数据集，当前数据集：YAGOIMG05926
# [21:37:22] 已转换4000/15404个数据集，当前数据集：YAGOIMG05402
# [21:37:22] 已转换4100/15404个数据集，当前数据集：YAGOIMG09471
# [21:37:22] 已转换4200/15404个数据集，当前数据集：YAGOIMG00079
# [21:37:22] 已转换4300/15404个数据集，当前数据集：YAGOIMG04681
# [21:37:22] 已转换4400/15404个数据集，当前数据集：YAGOIMG02007
# [21:37:22] 已转换4500/15404个数据集，当前数据集：YAGOIMG01403
# [21:37:22] 已转换4600/15404个数据集，当前数据集：YAGOIMG02419
# [21:37:23] 已转换4700/15404个数据集，当前数据集：YAGOIMG04187
# [21:37:23] 已转换4800/15404个数据集，当前数据集：YAGOIMG00230
# [21:37:23] 已转换4900/15404个数据集，当前数据集：YAGOIMG04053
# [21:37:23] 已转换5000/15404个数据集，当前数据集：YAGOIMG07908
# [21:37:23] 已转换5100/15404个数据集，当前数据集：YAGOIMG07874
# [21:37:23] 已转换5200/15404个数据集，当前数据集：YAGOIMG02211
# [21:37:23] 已转换5400/15404个数据集，当前数据集：YAGOIMG02870
# [21:37:23] 已转换5500/15404个数据集，当前数据集：YAGOIMG01405
# [21:37:23] 已转换5600/15404个数据集，当前数据集：YAGOIMG03180
# [21:37:23] 已转换5700/15404个数据集，当前数据集：YAGOIMG01377
# [21:37:24] 已转换6000/15404个数据集，当前数据集：YAGOIMG01955
# [21:37:24] 已转换6100/15404个数据集，当前数据集：YAGOIMG03531
# [21:37:24] 已转换6200/15404个数据集，当前数据集：YAGOIMG01504
# [21:37:24] 已转换6300/15404个数据集，当前数据集：YAGOIMG03843
# [21:37:24] 已转换6400/15404个数据集，当前数据集：YAGOIMG06784
# [21:37:24] 已转换6500/15404个数据集，当前数据集：YAGOIMG00803
# [21:37:24] 已转换6700/15404个数据集，当前数据集：YAGOIMG05083
# [21:37:24] 已转换6800/15404个数据集，当前数据集：YAGOIMG05247
# [21:37:24] 已转换6900/15404个数据集，当前数据集：YAGOIMG03450
# [21:37:24] 已转换7000/15404个数据集，当前数据集：YAGOIMG04925
# [21:37:24] 已转换7200/15404个数据集，当前数据集：YAGOIMG06580
# [21:37:25] 已转换7400/15404个数据集，当前数据集：YAGOIMG07292
# [21:37:25] 已转换7500/15404个数据集，当前数据集：YAGOIMG07045
# [21:37:25] 已转换7600/15404个数据集，当前数据集：YAGOIMG03032
# [21:37:25] 已转换7900/15404个数据集，当前数据集：YAGOIMG09352
# [21:37:25] 已转换8000/15404个数据集，当前数据集：YAGOIMG05276
# [21:37:25] 已转换8200/15404个数据集，当前数据集：YAGOIMG08707
# [21:37:25] 已转换8300/15404个数据集，当前数据集：YAGOIMG06542
# [21:37:25] 已转换8400/15404个数据集，当前数据集：YAGOIMG00984
# [21:37:26] 已转换8500/15404个数据集，当前数据集：YAGOIMG08364
# [21:37:26] 已转换8600/15404个数据集，当前数据集：YAGOIMG07507
# [21:37:26] 已转换8800/15404个数据集，当前数据集：YAGOIMG07080
# [21:37:26] 已转换9000/15404个数据集，当前数据集：YAGOIMG06391
# [21:37:26] 已转换9100/15404个数据集，当前数据集：YAGOIMG01134
# [21:37:26] 已转换9200/15404个数据集，当前数据集：YAGOIMG01893
# [21:37:26] 已转换9300/15404个数据集，当前数据集：YAGOIMG06921
# [21:37:26] 已转换9600/15404个数据集，当前数据集：YAGOIMG09345
# [21:37:26] 已转换9700/15404个数据集，当前数据集：YAGOIMG01531
# [21:37:27] 已转换10000/15404个数据集，当前数据集：YAGOIMG09122
# [21:37:27] 已转换10100/15404个数据集，当前数据集：YAGOIMG02866
# [21:37:27] 已转换10200/15404个数据集，当前数据集：YAGOIMG06117
# [21:37:27] 已转换10300/15404个数据集，当前数据集：YAGOIMG05681
# [21:37:27] 已转换10600/15404个数据集，当前数据集：YAGOIMG07302
# [21:37:27] 已转换10800/15404个数据集，当前数据集：YAGOIMG00749
# [21:37:27] 已转换10900/15404个数据集，当前数据集：YAGOIMG00468
# [21:37:27] 已转换11000/15404个数据集，当前数据集：YAGOIMG00602
# [21:37:28] 已转换11100/15404个数据集，当前数据集：YAGOIMG07704
# [21:37:28] 已转换11200/15404个数据集，当前数据集：YAGOIMG07756
# [21:37:28] 已转换11300/15404个数据集，当前数据集：YAGOIMG00676
# [21:37:28] 已转换11400/15404个数据集，当前数据集：YAGOIMG01954
# [21:37:28] 已转换11500/15404个数据集，当前数据集：YAGOIMG07409
# [21:37:28] 已转换11800/15404个数据集，当前数据集：YAGOIMG02276
# [21:37:28] 已转换11900/15404个数据集，当前数据集：YAGOIMG00770
# [21:37:28] 已转换12000/15404个数据集，当前数据集：YAGOIMG06721
# [21:37:28] 已转换12100/15404个数据集，当前数据集：YAGOIMG05579
# [21:37:29] 已转换12300/15404个数据集，当前数据集：YAGOIMG06177
# [21:37:29] 已转换12400/15404个数据集，当前数据集：YAGOIMG09898
# [21:37:29] 已转换12500/15404个数据集，当前数据集：YAGOIMG03939
# [21:37:29] 已转换12900/15404个数据集，当前数据集：YAGOIMG08274
# [21:37:29] 已转换13000/15404个数据集，当前数据集：YAGOIMG09930
# [21:37:29] 已转换13100/15404个数据集，当前数据集：YAGOIMG09002
# [21:37:29] 已转换13200/15404个数据集，当前数据集：YAGOIMG00886
# [21:37:30] 已转换13300/15404个数据集，当前数据集：YAGOIMG05726
# [21:37:30] 已转换13400/15404个数据集，当前数据集：YAGOIMG04821
# [21:37:30] 已转换13500/15404个数据集，当前数据集：YAGOIMG06407
# [21:37:30] 已转换13600/15404个数据集，当前数据集：YAGOIMG00386
# [21:37:30] 已转换13700/15404个数据集，当前数据集：YAGOIMG08532
# [21:37:30] 已转换13800/15404个数据集，当前数据集：YAGOIMG00384
# [21:37:30] 已转换13900/15404个数据集，当前数据集：YAGOIMG08800
# [21:37:30] 已转换14000/15404个数据集，当前数据集：YAGOIMG04281
# [21:37:30] 已转换14100/15404个数据集，当前数据集：YAGOIMG09209
# [21:37:30] 已转换14300/15404个数据集，当前数据集：YAGOIMG08302
# [21:37:31] 已转换14700/15404个数据集，当前数据集：YAGOIMG07236
# [21:37:31] 已转换14900/15404个数据集，当前数据集：YAGOIMG09154
# [21:37:31] 已转换15100/15404个数据集，当前数据集：YAGOIMG05055
# [21:37:31] 已转换15200/15404个数据集，当前数据集：YAGOIMG05142
# [21:37:31] 已转换15300/15404个数据集，当前数据集：YAGOIMG10166
# [21:37:31] 已转换15400/15404个数据集，当前数据集：YAGOIMG07835
# [21:37:31] YAGO15K/img_features.pkl 保存成功
